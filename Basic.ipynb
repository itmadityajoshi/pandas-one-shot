# %%
"hello"
# Out:
# 'hello'

# %%
import pandas as pd   # type: ignore

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# key Data Structures
# Series = one list
# DataFrame = Full table

# %% [markdown]
# Panda Series
#
# Create Series
#
# sales = pd.series([2,3,5])

# %%
sales = pd.Series([2,3,5,4,8,7])

# %%
sales
# Out:
# 0    2
# 1    3
# 2    5
# 3    4
# 4    8
# 5    7
# dtype: int64

# %%
sales[2]
# Out:
# np.int64(5)

# %%
sales[0:2]
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
sales.values
# Out:
# array([2, 3, 5, 4, 8, 7])

# %%
sales.dtype
# Out:
# dtype('int64')

# %%
sales.head
# Out:
# <bound method NDFrame.head of 0    2
# 1    3
# 2    5
# 3    4
# 4    8
# 5    7
# dtype: int64>

# %%
sales.tail
# Out:
# <bound method NDFrame.tail of 0    2
# 1    3
# 2    5
# 3    4
# 4    8
# 5    7
# dtype: int64>

# %%
sales.sort_values(ascending=True)
# Out:
# 0    2
# 1    3
# 3    4
# 2    5
# 5    7
# 4    8
# dtype: int64

# %%
sales.isnull
# Out:
# <bound method Series.isnull of 0    2
# 1    3
# 2    5
# 3    4
# 4    8
# 5    7
# dtype: int64>

# %%
sales.head(2)
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
sales.count()
# Out:
# np.int64(6)

# %%
sales.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
sales.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# dtype: bool

# %%
sales + 1
# Out:
# 0    3
# 1    4
# 2    6
# 3    5
# 4    9
# 5    8
# dtype: int64

# %%
sales
# Out:
# 0    2
# 1    3
# 2    5
# 3    4
# 4    8
# 5    7
# dtype: int64

# %%
sales *2
# Out:
# 0     4
# 1     6
# 2    10
# 3     8
# 4    16
# 5    14
# dtype: int64

# %%
sales.tail(2)
# Out:
# 4    8
# 5    7
# dtype: int64

# %%
sales_missing = pd.Series([2, None, 5])

# %%
sales_missing.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
sales_missing.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
sales_missing.fillna(3)
# Out:
# 0    2.0
# 1    3.0
# 2    5.0
# dtype: float64

# %%
sales_missing = pd.Series([2, None, 5])

# %%
sales_missing =  sales_missing.fillna(3)

# %%
sales_missing
# Out:
# 0    2.0
# 1    3.0
# 2    5.0
# dtype: float64

# %%
si = pd.Series(data = [100,200,300,400,500], index=list('abcde'))

# %%
si
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
si.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5 entries, a to e
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 252.0+ bytes

# %%
df = pd.DataFrame({
    'age': [24,25,29],
    'city': ['Linz','Graz','Vienna']
    }, index=['Alice','Bob','Charlie']
)

# %%
print(df)
# Out:
#          age    city
# Alice     24    Linz
# Bob       25    Graz
# Charlie   29  Vienna

# %%
df['age']
# Out:
# Alice      24
# Bob        25
# Charlie    29
# Name: age, dtype: int64

# %%
print(df[df['age']>24])
# Out:
#          age    city
# Bob       25    Graz
# Charlie   29  Vienna

# %% [markdown]
# here 3 is number of rows and 2 is a number of colulmns.

# %%
df.shape
# Out:
# (3, 2)

# %%
si.shape
# Out:
# (5,)

# %%
df.columns
# Out:
# Index(['age', 'city'], dtype='object')

# %%
df.dtypes
# Out:
# age      int64
# city    object
# dtype: object

# %% [markdown]
# Accessing Data
# #using labels
# df.loc[1,'age']
#
# #using index
# df.iloc[1,0]

# %%
df
# Out:
#          age    city
# Alice     24    Linz
# Bob       25    Graz
# Charlie   29  Vienna

# %%
df.loc["Alice"]
# Out:
# age       24
# city    Linz
# Name: Alice, dtype: object

# %%
print(df.index)
# Out:
# Index(['Alice', 'Bob', 'Charlie'], dtype='object')

# %%
df.loc['Charlie']
# Out:
# age         29
# city    Vienna
# Name: Charlie, dtype: object

# %%
df.loc['Charlie', "city"]
# Out:
# 'Vienna'

# %%
df.iloc[1]
# Out:
# age       25
# city    Graz
# Name: Bob, dtype: object

# %%
df.iloc[2,0]
# Out:
# np.int64(29)

# %%
df.head()
# Out:
#          age    city
# Alice     24    Linz
# Bob       25    Graz
# Charlie   29  Vienna

# %%
df.tail()
# Out:
#          age    city
# Alice     24    Linz
# Bob       25    Graz
# Charlie   29  Vienna

# %%
df.count()
# Out:
# age     3
# city    3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Alice to Charlie
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     3 non-null      int64
#  1   city    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   26.000000
# std     2.645751
# min    24.000000
# 25%    24.500000
# 50%    25.000000
# 75%    27.000000
# max    29.000000
